# %% [markdown]
# ## Market Trends Over Time
# ### How have average prices for listings changed over the years in different cities or neighborhood?

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import folium
import requests

from config import geoapify_api_key

# Load the dataset
df = pd.read_csv ('../Resources/air bnb csv with edits.csv')

# %%
# Replace '-' with '/' to standardize the format (optional if needed)
df['host_since'] = df['host_since'].str.replace('-', '/')

# Convert 'host_since' directly to datetime with coercion for invalid parsing
df['host_since'] = pd.to_datetime(df['host_since'], errors='coerce')
# remove host sites where availability is 0/365 days
df = df[df['availability_365'] != 0]
df = df.rename(columns={'neighbourhood_group': 'City'})
# Out:
# C:\Users\mende\AppData\Local\Temp\ipykernel_16120\12782967.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['host_since'] = pd.to_datetime(df['host_since'], errors='coerce')

# %%
print(df.columns)
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'host_since', 'host_is_superhost',
#        'host_identity_verified', 'instant_bookable', 'accommodates',
#        'amenities', 'State', 'City', 'neighbourhood', 'latitude', 'longitude',
#        'property_type', 'room_type', 'bathrooms', 'bedrooms', 'beds', 'price',
#        'minimum_nights', 'maximum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Display all unique cities in the dataframe
unique_cities = df['City'].unique()
print(unique_cities)

# Optionally, you can display the cities as a list
city_list = unique_cities.tolist()
print(city_list)
# Out:
# ['Los Angeles' 'San Diego County' 'San Francisco' 'San Mateo'
#  'Saint Clara County' ' Santa Cruz' 'Chicago' 'Broward County' 'Hawaii'
#  'Kauai' 'Maui' 'Honolulu' 'Clark County' 'Manhattan' 'Brooklyn' 'Queens'
#  'Staten Island' 'Bronx' 'Nashville' 'Washington D.C' 'Seattle']
# ['Los Angeles', 'San Diego County', 'San Francisco', 'San Mateo', 'Saint Clara County', ' Santa Cruz', 'Chicago', 'Broward County', 'Hawaii', 'Kauai', 'Maui', 'Honolulu', 'Clark County', 'Manhattan', 'Brooklyn', 'Queens', 'Staten Island', 'Bronx', 'Nashville', 'Washington D.C', 'Seattle']

# %%
# Group by city and get unique latitude and longitude for each city
city_coordinates = df.groupby('City')[['latitude', 'longitude']].first().reset_index()

# Display the result
print(city_coordinates)
# Out:
#                   City  latitude  longitude
# 0           Santa Cruz  36.98184 -121.88298
# 1                Bronx  40.80640  -73.92395
# 2             Brooklyn  40.68514  -73.95976
# 3       Broward County  26.01670  -80.12437
# 4              Chicago  41.78790  -87.58780
# 5         Clark County  36.10520 -115.16777
# 6               Hawaii  20.04095 -155.43251
# 7             Honolulu  21.65231 -158.06191
# 8                Kauai  21.88305 -159.47372
# 9          Los Angeles  33.98209 -118.38494
# 10           Manhattan  40.75362  -73.98377
# 11                Maui  20.75470 -156.45666
# 12           Nashville  36.17315  -86.73581
# 13              Queens  40.74771  -73.94740
# 14  Saint Clara County  37.34342 -121.98829
# 15    San Diego County  32.78430 -117.25258
# 16       San Francisco  37.77028 -122.43317
# 17           San Mateo  37.43118 -122.19654
# 18             Seattle  47.61082 -122.29082
# 19       Staten Island  40.64633  -74.08156
# ...

# %%
# Extract the year from the host_since or relevant date column
df['year'] = df['host_since'].dt.year

# Group by year and city/neighborhood, calculating the mean price
average_price_trends = df.groupby(['year', 'City'])['price'].mean().reset_index()

# Remove rows with NaN values (if necessary)
average_price_trends = average_price_trends.dropna(subset=['year', 'price'])

# Set the style
sns.set(style="whitegrid")

# Plot a line plot for each neighborhood over time
plt.figure(figsize=(14, 8))
sns.lineplot(data=average_price_trends, x='year', y='price', hue='City')

# Customize the plot
plt.title('Average Listing Price Over the Years by City')
plt.xlabel('Year')
plt.ylabel('Average Price ($)')
plt.legend(title='City', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()
folder_path = '../output_data'
file_path = os.path.join(folder_path, 'Line_average_listing_price_over_the_years_by_city.png')
plt.savefig(file_path, bbox_inches='tight')

# %%
plt.figure(figsize=(12, 8))
pivot_table = average_price_trends.pivot(index='year', columns='City', values='price')

# Create the heatmap with annotations formatted to no decimals
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap='YlGnBu')

# Update y-axis labels to display full 4-digit year values
# Ensure the y-ticks are displayed as 4-digit integers (e.g., 2012, 2013, ...)
plt.gca().set_yticklabels([str(int(year)) for year in pivot_table.index])

plt.title('Average Listing Price Over the Years by City')
plt.xlabel('City')
plt.ylabel('Year')
plt.show()
folder_path = '../output_data'
file_path = os.path.join(folder_path, 'Heatmap_average_listing_price_over_the_years_by_city.png')
plt.savefig(file_path, bbox_inches='tight')

# %%
average_prices = df.groupby("City")["price"].mean().reset_index()
print(average_prices)
# Out:
#                   City       price
# 0           Santa Cruz  287.237885
# 1                Bronx   94.201044
# 2             Brooklyn  127.695922
# 3       Broward County  195.229724
# 4              Chicago  154.750608
# 5         Clark County  200.214749
# 6               Hawaii  272.635874
# 7             Honolulu  257.656375
# 8                Kauai  324.682457
# 9          Los Angeles  234.997259
# 10           Manhattan  192.055952
# 11                Maui  336.438732
# 12           Nashville  214.506398
# 13              Queens  108.557995
# 14  Saint Clara County  157.533668
# 15    San Diego County  226.518168
# 16       San Francisco  195.444568
# 17           San Mateo  187.808885
# 18             Seattle  133.657290
# 19       Staten Island  111.897872
# 20      Washington D.C  174.407831

# %%
import folium
import pandas as pd
from config import geoapify_api_key

# Your data (City and average price)
data = [
    {"city": "Santa Cruz", "price": 287.237885},
    {"city": "Bronx", "price": 94.201044},
    {"city": "Brooklyn", "price": 127.695922},
    {"city": "Broward County", "price": 195.229724},
    {"city": "Chicago", "price": 154.750608},
    {"city": "Clark County", "price": 200.214749},
    {"city": "Hawaii", "price": 272.635874},
    {"city": "Honolulu", "price": 257.656375},
    {"city": "Kauai", "price": 324.682457},
    {"city": "Los Angeles", "price": 234.997259},
    {"city": "Manhattan", "price": 192.055952},
    {"city": "Maui", "price": 336.438732},
    {"city": "Nashville", "price": 214.506398},
    {"city": "Queens", "price": 108.557995},
    {"city": "Saint Clara County", "price": 157.533668},
    {"city": "San Diego County", "price": 226.518168},
    {"city": "San Francisco", "price": 195.444568},
    {"city": "San Mateo", "price": 187.808885},
    {"city": "Seattle", "price": 133.657290},
    {"city": "Staten Island", "price": 111.897872},
    {"city": "Washington D.C", "price": 174.407831}
]

# Create a DataFrame from the data
average_prices = pd.DataFrame(data)

# List of cities and their latitude/longitude
cities_data = [
    {"city": "Santa Cruz", "latitude": 36.9741, "longitude": -122.0308},
    {"city": "Bronx", "latitude": 40.8448, "longitude": -73.8648},
    {"city": "Brooklyn", "latitude": 40.6782, "longitude": -73.9442},
    {"city": "Broward County", "latitude": 26.1901, "longitude": -80.3659},
    {"city": "Chicago", "latitude": 41.8781, "longitude": -87.6298},
    {"city": "Clark County", "latitude": 36.0395, "longitude": -115.1645},
    {"city": "Hawaii", "latitude": 20.7984, "longitude": -156.3319},
    {"city": "Honolulu", "latitude": 21.3069, "longitude": -157.8583},
    {"city": "Kauai", "latitude": 22.0964, "longitude": -159.5261},
    {"city": "Los Angeles", "latitude": 34.0522, "longitude": -118.2437},
    {"city": "Manhattan", "latitude": 40.7831, "longitude": -73.9712},
    {"city": "Maui", "latitude": 20.7984, "longitude": -156.3319},
    {"city": "Nashville", "latitude": 36.1627, "longitude": -86.7816},
    {"city": "Queens", "latitude": 40.7282, "longitude": -73.7949},
    {"city": "Saint Clara County", "latitude": 37.3541, "longitude": -121.9552},
    {"city": "San Diego County", "latitude": 32.7157, "longitude": -117.1611},
    {"city": "San Francisco", "latitude": 37.7749, "longitude": -122.4194},
    {"city": "San Mateo", "latitude": 37.5629, "longitude": -122.3255},
    {"city": "Seattle", "latitude": 47.6062, "longitude": -122.3321},
    {"city": "Staten Island", "latitude": 40.5795, "longitude": -74.1502},
    {"city": "Washington D.C", "latitude": 38.9072, "longitude": -77.0369}
]

# Merge average prices with city data based on city names
for city_data in cities_data:
    city_data['avg_price'] = average_prices[average_prices['city'] == city_data['city']]['price'].values[0]

# Create the map centered on a general location (New York as an example)
mymap = folium.Map(location=[40.7128, -74.0060], zoom_start=5)

# Add markers for each city with the average price
for city_data in cities_data:
    price = city_data['avg_price']
    color = 'green' if price < 150 else ('orange' if price < 250 else 'red')  # Color based on price range
    folium.Marker(
        location=[city_data['latitude'], city_data['longitude']],
        popup=f"{city_data['city']}<br>Average Price: ${city_data['avg_price']:.2f}",
        icon=folium.Icon(color=color)
    ).add_to(mymap)

# Save the map as an HTML file
mymap.save("geoapify_map_with_prices.html")
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Seasonality and Demand Patterns:
# ### Are there consistent peak and low seasons for Airbnb bookings in specific cities?

# %% [markdown]
# ## Guest Preferences Over Time:
# ### How have guest preferences shifted over time in terms of property types (e.g., entire home/apartment vs. private room)?
